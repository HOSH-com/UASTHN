# %%
# !python ./local_pipeline/js_myevaluate.py --eval_model model.pt --device cuda:0 --satellite_dir js_datasets/Dehat/satellite --thermal_dir js_datasets/Dehat/thermal --output_excel js_excels/new.xlsx --num_samples 108 --tiles_per_satellite 9
# Out:
# 2026-05-02 06:38:40.188934400 [W:onnxruntime:Default, device_discovery.cc:164 DiscoverDevicesForPlatform] GPU device discovery failed: device_discovery.cc:89 ReadFileContents Failed to open file: "/sys/class/drm/card1/device/vendor"
# [sudo] password for rpl:
# sudo: a password is required
# /home/rpl/.local/lib/python3.10/site-packages/torch/backends/__init__.py:42: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /opt/pytorch/aten/src/ATen/Context.cpp:80.)
#   return self.getter()
# ^C
# Traceback (most recent call last):
#   File "/home/rpl/Desktop/RPL/Map-Matching/UASTHN/./local_pipeline/js_myevaluate.py", line 313, in <module>
#     run_js_loop(parse_cli_args())
#   File "/home/rpl/Desktop/RPL/Map-Matching/UASTHN/./local_pipeline/js_myevaluate.py", line 196, in run_js_loop
#     model = UASTHN(args)
#   File "/home/rpl/Desktop/RPL/Map-Matching/UASTHN/local_pipeline/model/network.py", line 208, in __init__
#     self.four_point_org_single = torch.zeros((1, 2, 2, 2)).to(self.device)
#   File "/home/rpl/.local/lib/python3.10/site-packages/torch/cuda/__init__.py", line 421, in _lazy_init
#     queued_call()
#   File "/home/rpl/.local/lib/python3.10/site-packages/torch/cuda/__init__.py", line 268, in _check_capability
#     for d in range(device_count()):
#   File "/home/rpl/.local/lib/python3.10/site-packages/torch/cuda/__init__.py", line 1033, in device_count
#     nvml_count = _device_count_amdsmi() if torch.version.hip else _device_count_nvml()
#   File "/home/rpl/.local/lib/python3.10/site-packages/torch/cuda/__init__.py", line 984, in _device_count_nvml
#     raw_cnt = _raw_device_count_nvml()
#   File "/home/rpl/.local/lib/python3.10/site-packages/torch/cuda/__init__.py", line 825, in _raw_device_count_nvml
#     rc = nvml_h.nvmlInit()
# KeyboardInterrupt
