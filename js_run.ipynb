# %%
# !python UASTHN\local_pipeline\js_myevaluate.py --eval_model model.pt --device cuda:0 --satellite_dir js_datasets/Dehat/satellite --thermal_dir js_datasets/Dehat/thermal --output_excel js_excels/new.xlsx --num_samples 108 --tiles_per_satellite 9
# Out:
# Done image 1/108 in 3.281 sec
# Done image 2/108 in 0.086 sec
# Done image 3/108 in 0.085 sec
# Done image 4/108 in 0.086 sec
# Done image 5/108 in 0.085 sec
# Done image 6/108 in 0.093 sec
# Done image 7/108 in 0.083 sec
# Done image 8/108 in 0.082 sec
# Done image 9/108 in 0.090 sec
# Done image 10/108 in 0.080 sec
# Done image 11/108 in 0.082 sec
# Done image 12/108 in 0.087 sec
# Done image 13/108 in 0.081 sec
# Done image 14/108 in 0.086 sec
# Done image 15/108 in 0.087 sec
# Done image 16/108 in 0.088 sec
# Done image 17/108 in 0.104 sec
# Done image 18/108 in 0.091 sec
# Done image 19/108 in 0.098 sec
# Done image 20/108 in 0.086 sec
# Done image 21/108 in 0.086 sec
# Done image 22/108 in 0.094 sec
# Done image 23/108 in 0.087 sec
# Done image 24/108 in 0.088 sec
# Done image 25/108 in 0.091 sec
# Done image 26/108 in 0.089 sec
# Done image 27/108 in 0.081 sec
# Done image 28/108 in 0.083 sec
# Done image 29/108 in 0.081 sec
# Done image 30/108 in 0.085 sec
# ...
